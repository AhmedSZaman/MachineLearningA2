# %%
import gym
from gym import spaces
import numpy as np

class ThreeQueueEnvironment(gym.Env):
    def __init__(self):
        self.action_space = spaces.Discrete(3)
        self.observation_space = spaces.Box(low=0, high=np.inf, shape=(3,), dtype=float)
        
        self.queue_rate = [0.3, 0.25, 0.4]
        
        self.queue_packet_progress = [0,0,0]
        
        self.total_packets = [0,0,0]
        
        self.mean_packet_delay = [0,0,0]
        
        self.time = 1000
    
    def step(self, action):
        prev_queue3_delay = self.queue3_delay
        
        for i in range(self.queue_packet_progress):
            self.queue_packet_progress[i] += self.queue_rate[i]
        
        
        
        if action == 0:
            if self.queue1_delay >= 1 :
                self.queue1_delay -= 1
        elif action == 1:
            if self.queue2_delay >= 1:
                self.queue2_delay -= 1
        elif action == 2:
            if self.queue3_delay >= 1:
                self.queue3_delay -= 1
        
        
        observation = np.array([self.queue1_delay, self.queue2_delay, self.queue3_delay])
        reward = 0
        if self.queue1_delay > 6 or self.queue2_delay > 4:
            reward = -1
        if self.queue3_delay < prev_queue3_delay:
            reward = 1
            
        self.time -= 1
        done = self.time <= 0  # You can define the termination condition based on your specific criteria

        return observation, reward, done, {}
    
    def reset(self):
        self.queue1_delay = 0
        self.queue2_delay = 0
        self.queue3_delay = 0
        
        observation = np.array([self.queue1_delay, self.queue2_delay, self.queue3_delay])
        return observation
    
    def render(self):
        print("Queue 1 Delay:", self.queue1_delay)
        print("Queue 2 Delay:", self.queue2_delay)
        print("Queue 3 Delay:", self.queue3_delay)

# Test the ThreeQueueEnvironment
env = ThreeQueueEnvironment()
observation = env.reset()

for _ in range(100):
    action = env.action_space.sample()
    print(action)
    next_observation, reward, done, _ = env.step(action)
    env.render()
    print("Reward:", reward)
    print("Done:", done)
    print("--------------------")
# Out:
# 0
# Queue 1 Delay: 0.3
# Queue 2 Delay: 0.4
# Queue 3 Delay: 0.4
# Reward: 0
# Done: False
# --------------------
# 0
# Queue 1 Delay: 0.6
# Queue 2 Delay: 0.8
# Queue 3 Delay: 0.8
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 0.8999999999999999
# Queue 2 Delay: 0.20000000000000018
# Queue 3 Delay: 1.2000000000000002
# Reward: 0
# Done: False
# --------------------
# 0
# Queue 1 Delay: 0.19999999999999996
# Queue 2 Delay: 0.6000000000000002
# Queue 3 Delay: 1.6
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 0.49999999999999994
# Queue 2 Delay: 2.220446049250313e-16
# Queue 3 Delay: 2.0
# Reward: 0
# Done: False
# --------------------
# 0
# Queue 1 Delay: 0.7999999999999999
# Queue 2 Delay: 0.40000000000000024
# Queue 3 Delay: 2.4
# Reward: 0
# Done: False
# --------------------
# 2
# Queue 1 Delay: 1.0999999999999999
# Queue 2 Delay: 0.8000000000000003
# Queue 3 Delay: 1.7999999999999998
# Reward: 1
# Done: False
# --------------------
# 0
# Queue 1 Delay: 0.3999999999999999
# Queue 2 Delay: 1.2000000000000002
# Queue 3 Delay: 2.1999999999999997
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 0.7
# Queue 2 Delay: 0.6000000000000001
# Queue 3 Delay: 2.5999999999999996
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 1.0
# Queue 2 Delay: 0.0
# Queue 3 Delay: 2.9999999999999996
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 1.3
# Queue 2 Delay: 0.4
# Queue 3 Delay: 3.3999999999999995
# Reward: 0
# Done: False
# --------------------
# 2
# Queue 1 Delay: 1
# Reward: 0
# Done: False
# --------------------
# 2
# Queue 1 Delay: 2.000000000000001
# Queue 2 Delay: 0.9999999999999993
# Queue 3 Delay: 10.000000000000007
# Reward: 1
# Done: False
# --------------------
# 2
# Queue 1 Delay: 2.3000000000000007
# Queue 2 Delay: 1.3999999999999995
# Queue 3 Delay: 9.400000000000007
# Reward: 1
# Done: False
# --------------------
# 2
# Queue 1 Delay: 2.6000000000000005
# Queue 2 Delay: 1.7999999999999994
# Queue 3 Delay: 8.800000000000008
# Reward: 1
# Done: False
# --------------------
# 0
# Queue 1 Delay: 1.9000000000000004
# Queue 2 Delay: 2.1999999999999993
# Queue 3 Delay: 9.200000000000008
# Reward: 0
# Done: False
# --------------------
# 0
# Queue 1 Delay: 1.2000000000000002
# Queue 2 Delay: 2.599999999999999
# Queue 3 Delay: 9.600000000000009
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 1.5000000000000002
# Queue 2 Delay: 1.9999999999999991
# Queue 3 Delay: 10.000000000000009
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 1.8000000000000003
# Queue 2 Delay: 1.399999999999999
# Queue 3 Delay: 10.40000000000001
# Reward: 0
# Done: False
# --------------------
# 0
# Queue 1 Delay: 1.1
# Queue 2 Delay: 1.799999999999999
# Queue 3 Delay: 10.80000000000001
# Reward: 0
# Done: False
# --------------------
# 0
# Queue 1 Delay: 0.40000000000000013
# Queue 2 Delay: 2.199999999999999
# Queue 3 Delay: 11.20000000000001
# Reward: 0
# Done: False
# --------------------
# 2
# Queue 1 Delay: 0.7000000000000002
# Queue 2 Delay: 2.5999999999999988
# Queue 3 Delay: 10.60000000000001
# Reward: 1
# Done: False
# --------------------
# 1
# Queue 1 Delay: 1.0000000000000002
# Queue 2 Delay: 1.9999999999999987
# Queue 3 Delay: 11.00000000000001
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 1.3000000000000003
# Queue 2 Delay: 1.3999999999999986
# Queue 3 Delay: 11.400000000000011
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 1.6000000000000003
# Queue 2 Delay: 0.7999999999999985
# Queue 3 Delay: 11.800000000000011
# Reward: 0
# Done: False
# --------------------
# 2
# Queue 1 Delay: 1.9000000000000004
# Queue 2 Delay: 1.1999999999999984
# Queue 3 Delay: 11.200000000000012
# Reward: 1
# Done: False
# --------------------
# 1
# Queue 1 Delay: 2.2
# Queue 2 Delay: 0.5999999999999983
# Queue 3 Delay: 11.600000000000012
# Reward: 0
# Done: False
# --------------------
# 0
# Queue 1 Delay: 1.5
# Queue 2 Delay: 0.9999999999999983
# Queue 3 Delay: 12.000000000000012
# Reward: 0
# Done: False
# --------------------
# 0
# Queue 1 Delay: 0.8
# Queue 2 Delay: 1.3999999999999984
# Queue 3 Delay: 12.400000000000013
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 1.1
# Queue 2 Delay: 0.7999999999999985
# Queue 3 Delay: 12.800000000000013
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 1.4000000000000001
# Queue 2 Delay: 0.1999999999999984
# Queue 3 Delay: 13.200000000000014
# Reward: 0
# Done: False
# --------------------
# 0
# Queue 1 Delay: 0.7000000000000002
# Queue 2 Delay: 0.5999999999999984
# Queue 3 Delay: 13.600000000000014
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 1.0000000000000002
# Queue 2 Delay: 0.9999999999999984
# Queue 3 Delay: 14.000000000000014
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 1.3000000000000003
# Queue 2 Delay: 0.3999999999999986
# Queue 3 Delay: 14.400000000000015
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 1.6000000000000003
# Queue 2 Delay: 0.7999999999999986
# Queue 3 Delay: 14.800000000000015
# Reward: 0
# Done: False
# --------------------
# 0
# Queue 1 Delay: 0.9000000000000004
# Queue 2 Delay: 1.1999999999999986
# Queue 3 Delay: 15.200000000000015
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 1.2000000000000004
# Queue 2 Delay: 0.5999999999999988
# Queue 3 Delay: 15.600000000000016
# Reward: 0
# Done: False
# --------------------
# 2
# Queue 1 Delay: 1.5000000000000004
# Queue 2 Delay: 0.9999999999999988
# Queue 3 Delay: 15.000000000000014
# Reward: 1
# Done: False
# --------------------
# 0
# Queue 1 Delay: 0.8000000000000005
# Queue 2 Delay: 1.3999999999999988
# Queue 3 Delay: 15.400000000000015
# Reward: 0
# Done: False
# --------------------
# 0
# Queue 1 Delay: 0.10000000000000053
# Queue 2 Delay: 1.799999999999999
# Queue 3 Delay: 15.800000000000015
# Reward: 0
# Done: False
# --------------------
# 0
# Queue 1 Delay: 0.4000000000000005
# Queue 2 Delay: 2.199999999999999
# Queue 3 Delay: 16.200000000000014
# Reward: 0
# Done: False
# --------------------
# 2
# Queue 1 Delay: 0.7000000000000005
# Queue 2 Delay: 2.5999999999999988
# Queue 3 Delay: 15.600000000000012
# Reward: 1
# Done: False
# --------------------
# 0
# Queue 1 Delay: 4.440892098500626e-16
# Queue 2 Delay: 2.9999999999999987
# Queue 3 Delay: 16.00000000000001
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 0.30000000000000043
# Queue 2 Delay: 2.3999999999999986
# Queue 3 Delay: 16.40000000000001
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 0.6000000000000004
# Queue 2 Delay: 1.7999999999999985
# Queue 3 Delay: 16.800000000000008
# Reward: 0
# Done: False
# --------------------
# 0
# Queue 1 Delay: 0.9000000000000004
# Queue 2 Delay: 2.1999999999999984
# Queue 3 Delay: 17.200000000000006
# Reward: 0
# Done: False
# --------------------
# 0
# Queue 1 Delay: 0.2000000000000004
# Queue 2 Delay: 2.5999999999999983
# Queue 3 Delay: 17.600000000000005
# Reward: 0
# Done: False
# --------------------
# 0
# Queue 1 Delay: 0.5000000000000004
# Queue 2 Delay: 2.9999999999999982
# Queue 3 Delay: 18.000000000000004
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 0.8000000000000005
# Queue 2 Delay: 2.399999999999998
# Queue 3 Delay: 18.400000000000002
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 1.1000000000000005
# Queue 2 Delay: 1.799999999999998
# Queue 3 Delay: 18.8
# Reward: 0
# Done: False
# --------------------
# 2
# Queue 1 Delay: 1.4000000000000006
# Queue 2 Delay: 2.199999999999998
# Queue 3 Delay: 18.2
# Reward: 1
# Done: False
# --------------------
# 0
# Queue 1 Delay: 0.7000000000000006
# Queue 2 Delay: 2.599999999999998
# Queue 3 Delay: 18.599999999999998
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 1.0000000000000007
# Queue 2 Delay: 1.9999999999999978
# Queue 3 Delay: 18.999999999999996
# Reward: 0
# Done: False
# --------------------
# 2
# Queue 1 Delay: 1.3000000000000007
# Queue 2 Delay: 2.3999999999999977
# Queue 3 Delay: 18.399999999999995
# Reward: 1
# Done: False
# --------------------
# 0
# Queue 1 Delay: 0.6000000000000008
# Queue 2 Delay: 2.7999999999999976
# Queue 3 Delay: 18.799999999999994
# Reward: 0
# Done: False
# --------------------
# 0
# Queue 1 Delay: 0.9000000000000008
# Queue 2 Delay: 3.1999999999999975
# Queue 3 Delay: 19.199999999999992
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 1.2000000000000008
# Queue 2 Delay: 2.5999999999999974
# Queue 3 Delay: 19.59999999999999
# Reward: 0
# Done: False
# --------------------
# 0
# Queue 1 Delay: 0.5000000000000009
# Queue 2 Delay: 2.9999999999999973
# Queue 3 Delay: 19.99999999999999
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 0.8000000000000009
# Queue 2 Delay: 2.3999999999999972
# Queue 3 Delay: 20.399999999999988
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 1.100000000000001
# Queue 2 Delay: 1.7999999999999972
# Queue 3 Delay: 20.799999999999986
# Reward: 0
# Done: False
# --------------------
# 0
# Queue 1 Delay: 0.400000000000001
# Queue 2 Delay: 2.199999999999997
# Queue 3 Delay: 21.199999999999985
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 0.7000000000000011
# Queue 2 Delay: 1.599999999999997
# Queue 3 Delay: 21.599999999999984
# Reward: 0
# Done: False
# --------------------
# 0
# Queue 1 Delay: 1.1102230246251565e-15
# Queue 2 Delay: 1.999999999999997
# Queue 3 Delay: 21.999999999999982
# Reward: 0
# Done: False
# --------------------
# 0
# Queue 1 Delay: 0.3000000000000011
# Queue 2 Delay: 2.399999999999997
# Queue 3 Delay: 22.39999999999998
# Reward: 0
# Done: False
# --------------------
# 1
# Queue 1 Delay: 0.6000000000000011
# Queue 2 Delay: 1.7999999999999967
# Queue 3 Delay: 22.79999999999998
# Reward: 0
# Done: False
# --------------------
# 0
# Queue 1 Delay: 0.900000000000001
# Queue 2 Delay: 2.1999999999999966
# Queue 3 Delay: 23.199999999999978
# Reward: 0
# Done: False
# --------------------
# 2
# Queue 1 Delay: 1.200000000000001
# Queue 2 Delay: 2.5999999999999965
# Queue 3 Delay: 22.599999999999977
# Reward: 1
# Done: False
# --------------------
# 2
# Queue 1 Delay: 1.500000000000001
# Queue 2 Delay: 2.9999999999999964
# Queue 3 Delay: 21.999999999999975
# Reward: 1
# Done: False
# --------------------
# 2
# Queue 1 Delay: 1.8000000000000012
# Queue 2 Delay: 3.3999999999999964
# Queue 3 Delay: 21.399999999999974
# Reward: 1
# Done: False
# --------------------
# 1
# Queue 1 Delay: 2.100000000000001
# Queue 2 Delay: 2.7999999999999963
# Queue 3 Delay: 21.799999999999972
# Reward: 0
# Done: False
# --------------------
# 2
# Queue 1 Delay: 2.400000000000001
# Queue 2 Delay: 3.199999999999996
# Queue 3 Delay: 21.19999999999997
# Reward: 1
# Done: False
# --------------------
# 1
# Queue 1 Delay: 2.7000000000000006
# Queue 2 Delay: 2.599999999999996
# Queue 3 Delay: 21.59999999999997
# Reward: 0
# Done: False
# --------------------
# 0
# Queue 1 Delay: 2.0000000000000004
# Queue 2 Delay: 2.999999999999996
# Queue 3 Delay: 21.999999999999968
# Reward: 0
# Done: False
# --------------------

# %%
import gym
import numpy as np

class DiscretizedObservationWrapper(gym.ObservationWrapper):
    def __init__(self, env, bins):
        super().__init__(env)
        self.bins = bins
        self.observation_space = gym.spaces.Discrete(np.prod(bins))

    def observation(self, observation):
        # Discretize the continuous observation
        discrete_obs = np.zeros_like(observation, dtype=np.int)
        for i, obs in enumerate(observation):
            discrete_obs[i] = obs
        return tuple(discrete_obs)

# Define the continuous observation space
continuous_obs_space = env.observation_space

# Define the number of bins for each dimension of the observation space
bins = [3] * len(continuous_obs_space.high)  # Adjust the number of bins as needed

# Create the discretized observation wrapper
env = DiscretizedObservationWrapper(env, bins)

# Now you can use the discretized observation space in a Q-learning model
# ...
env.observation_space
# Out:
# Discrete(27)

# %%
observation = env.reset()
done = False
while not done:
    action = env.action_space.sample()
    next_observation, reward, done, _ = env.step(action)
    env.render()
    print("Observation:", next_observation)
    print("Reward:", reward)
    print("Done:", done)
    print("--------------------")

env.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 observation = env.reset()
#       2 done = False
#       3 while not done:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\core.py:379, in ObservationWrapper.reset(self, **kwargs)
#     377 def reset(self, **kwargs):
#     378     """Resets the environment, returning a modified observation using :meth:`self.observation`."""
# --> 379     obs, info = self.env.reset(**kwargs)
#     380     return self.observation(obs), info
#
# ValueError: too many values to unpack (expected 2)

# %%
def encode(delay_1, delay_2, delay_3)
